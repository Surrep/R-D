# %%
from scipy.io.wavfile import read, write
from IPython.display import Audio
from auto_chunks import AutoRNN

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sounds = '/Users/tru/Desktop/english/'
sample_rate, data = read(sounds + 'calc.wav')

X = (data.reshape(1, -1) / np.max(data))[:, 55000:60000]
y = X

arnn = AutoRNN(learning_rate=0.1, seq_len=100,
               look_ahead=2, stride=2, lucidity=0)

arnn.fit(X, y, epsilon=1e-13, cap=1000, verbose=True)
out2 = arnn.generate(seed=X[:,:25], num_samples=5000)

plt.plot(X.reshape(-1)[:2150])
plt.show()

plt.plot(out2.reshape(-1)[:2150])
plt.show()

Audio(out2, rate=40000)
# Out:
# 0 184 9.4291429884e-14
# 1000 30 6.47815626246e-14
# 2000 43 9.15354643544e-14
# 3000 124 8.51451901073e-14
# 4000 89 9.31663253437e-14
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
